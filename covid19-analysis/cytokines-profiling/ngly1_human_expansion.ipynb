# %% [markdown]
# # Expansion of nodes using Monarch APIs
# * https://api.monarchinitiative.org/api/#/
# * https://scigraph-ontology.monarchinitiative.org/scigraph/docs/#/

# %%
import pandas as pd
import requests
import json
from pandas.io.json import json_normalize

# %%
# input gene
gene = 'NCBIGene:55768'

# output files
path = 'ngly1-human-expansion/ngly1_human'

# %% [markdown]
# ## Graph queries (SciGraph)

# %%
# api address
api = 'https://scigraph-ontology.monarchinitiative.org/scigraph'
endpoint = '/graph'

# %%
# get neighbors (JSON content)
r = requests.get('{}{}/neighbors/{}'.format(api,endpoint,gene))
r.headers
# Out:
# {'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'nginx/1.10.0 (Ubuntu)', 'Content-Encoding': 'gzip', 'Content-Type': 'application/json', 'Vary': 'Accept, Accept-Encoding', 'Cache-Control': 'no-transform, max-age=7200', 'Date': 'Tue, 23 May 2017 21:21:37 GMT'}

# %%
# Read results 
r.json()
# Out:
# {'edges': [{'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12477932'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14749736'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15610852'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['in taxon']},
#    'obj': 'NCBITaxon:9606',
#    'pred': 'RO:0002162',
#    'sub': 'NCBIGene:55768'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25220016'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:10831608'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15358861'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['term replaced by'],
#     'owlType': ['Annotation']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0100001',
#    'sub': 'NCBIGene:80175'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15362974'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18187620'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['equivalentClass']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'equivalentClass',
#    'sub': 'HGNC:17646'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11562482'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['equivalentClass']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'equivalentClass',
#    'sub': 'ENSEMBL:ENSG00000151092'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20668520'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25416956'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['term replaced by'],
#     'owlType': ['Annotation']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0100001',
#    'sub': 'NCBIGene:95041'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26344197'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25900930'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22190034'},
#   {'meta': {'lbl': ['isDefinedBy']},
#    'obj': 'MonarchData:ncbigene.ttl',
#    'pred': 'isDefinedBy',
#    'sub': 'NCBIGene:55768'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22268729'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15489334'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25398991'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24797263'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16055502'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24651605'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22119785'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14702039'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['subClassOf']},
#    'obj': 'SO:0001217',
#    'pred': 'subClassOf',
#    'sub': 'NCBIGene:55768'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23602568'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['equivalentClass']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'equivalentClass',
#    'sub': 'OMIM:610661'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26186194'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16807242'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['is subsequence of']},
#    'obj': 'CHR:9606chr3p24.2',
#    'pred': 'RO:0002525',
#    'sub': 'NCBIGene:55768'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22575648'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21832049'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:55768',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17015730'}],
#  'meta': {},
#  'nodes': [{'id': 'PMID:10831608',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'MonarchData:ncbigene.ttl',
#    'lbl': None,
#    'meta': {'types': ['Ontology', 'cliqueLeader', 'Node']}},
#   {'id': 'PMID:22190034',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16055502',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'OMIM:610661',
#    'lbl': None,
#    'meta': {'category': ['gene', 'sequence feature'],
#     'types': ['gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'NCBIGene:55768',
#    'lbl': 'NGLY1',
#    'meta': {'category': ['gene', 'sequence feature'],
#     'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1'],
#     'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['FLJ12409',
#      'LOC95041',
#      'N-glycanase 1'],
#     'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#      'PNGase',
#      'hPNGase',
#      'CDG1V',
#      'CDDG',
#      'PNG1',
#      'peptide:N-glycanase'],
#     'http://www.w3.org/2000/01/rdf-schema#label': ['NGLY1'],
#     'synonym': ['FLJ12409',
#      'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#      'LOC95041',
#      'N-glycanase 1',
#      'PNGase',
#      'hPNGase',
#      'CDG1V',
#      'CDDG',
#      'PNG1',
#      'peptide:N-glycanase'],
#     'types': ['cliqueLeader', 'gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'SO:0001217',
#    'lbl': 'protein_coding_gene',
#    'meta': {'category': ['gene', 'sequence feature'],
#     'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['protein coding gene'],
#     'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': ['sequence'],
#     'http://www.geneontology.org/formats/oboInOwl#id': ['SO:0001217'],
#     'http://www.w3.org/2000/01/rdf-schema#label': ['protein_coding_gene'],
#     'synonym': ['protein coding gene'],
#     'types': ['cliqueLeader', 'gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'PMID:15610852',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26344197',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15362974',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23602568',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14702039',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22119785',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'ENSEMBL:ENSG00000151092',
#    'lbl': None,
#    'meta': {'category': ['gene', 'sequence feature'],
#     'types': ['gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'NCBIGene:95041',
#    'lbl': 'LOC95041',
#    'meta': {'http://www.w3.org/2000/01/rdf-schema#label': ['LOC95041'],
#     'http://www.w3.org/2002/07/owl#deprecated': [True],
#     'types': ['cliqueLeader', 'Node', 'Class']}},
#   {'id': 'PMID:20668520',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25416956',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14749736',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11562482',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'HGNC:17646',
#    'lbl': None,
#    'meta': {'category': ['gene', 'sequence feature'],
#     'types': ['gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'PMID:15358861',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'NCBITaxon:9606',
#    'lbl': 'Homo sapiens',
#    'meta': {'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['GC_ID:1'],
#     'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['man',
#      'human'],
#     'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': ['mondo',
#      'ncbi_taxonomy'],
#     'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['humans'],
#     'http://www.geneontology.org/formats/oboInOwl#id': ['NCBITaxon:9606'],
#     'http://www.w3.org/2000/01/rdf-schema#label': ['Homo sapiens'],
#     'synonym': ['man', 'humans', 'human'],
#     'types': ['cliqueLeader', 'Node', 'Class']}},
#   {'id': 'PMID:25398991',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15489334',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16807242',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25220016',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25900930',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22575648',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18187620',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'CHR:9606chr3p24.2',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:24651605',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:24797263',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12477932',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22268729',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'NCBIGene:80175',
#    'lbl': 'FLJ12409',
#    'meta': {'http://www.w3.org/2000/01/rdf-schema#label': ['FLJ12409'],
#     'http://www.w3.org/2002/07/owl#deprecated': [True],
#     'types': ['cliqueLeader', 'Node', 'Class']}},
#   {'id': 'PMID:17015730',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26186194',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21832049',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}}]}

# %%
with open('{}_neighbors.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
neighbors_df = json_normalize(r.json(), 'nodes')
neighbors_df.head()
# Out:
#                          id   lbl  \
# 0             PMID:10831608  None
# 1  MonarchData:ncbigene.ttl  None
# 2             PMID:22190034  None
# 3             PMID:16055502  None
# 4               OMIM:610661  None
#
#                                                 meta
# 0  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 1    {'types': ['Ontology', 'cliqueLeader', 'Node']}
# 2  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 3  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 4  {'category': ['gene', 'sequence feature'], 'ty...

# %%
neighbors_df[neighbors_df.id.str.startswith('NCBIGene')]
# the other ncbigene terms are discontinued ones (replaced by ncbi:55768)
# Out:
#                 id       lbl  \
# 5   NCBIGene:55768     NGLY1
# 14  NCBIGene:95041  LOC95041
# 34  NCBIGene:80175  FLJ12409
#
#                                                  meta
# 5   {'http://www.geneontology.org/formats/oboInOwl...
# 14  {'http://www.w3.org/2000/01/rdf-schema#label':...
# 34  {'http://www.w3.org/2002/07/owl#deprecated': [...

# %%
# Analyze neighbours' types
neighbors_df.id.unique()
print('nodes: {}'.format(len(neighbors_df.id.unique())))
# Out:
# nodes: 38

# %%
neighbors_df['node_type'] = neighbors_df.id.apply(lambda x: x.split(':')[0])
neighbors_df.node_type.value_counts()
# Out:
# PMID           28
# NCBIGene        3
# CHR             1
# NCBITaxon       1
# OMIM            1
# MonarchData     1
# ENSEMBL         1
# SO              1
# HGNC            1
# Name: node_type, dtype: int64

# %%
# conclusion: neighbors are taxon, chr position, so, xref (ensembl, hgnc, omim) and provenance

# %%
# Filters
# Filter by interaction_type. BUT what are the strings per interaction_type???

# %%
# get reachable nodes (JSON content)
r = requests.get('{}{}/reachablefrom/{}'.format(api,endpoint,gene))
r.headers
# Out:
# {'Connection': 'keep-alive', 'Server': 'nginx/1.10.0 (Ubuntu)', 'Content-Length': '446', 'Content-Encoding': 'gzip', 'Content-Type': 'application/json', 'Vary': 'Accept, Accept-Encoding', 'Cache-Control': 'no-transform, max-age=7200', 'Date': 'Tue, 23 May 2017 21:21:40 GMT'}

# %%
# Read results 
r.json()
reach_df = json_normalize(r.json(), 'nodes')
reach_df.head()
# Out:
#                          id                  lbl  \
# 0         CHR:9606chr3p24.2                 None
# 1  MonarchData:ncbigene.ttl                 None
# 2            NCBITaxon:9606         Homo sapiens
# 3                SO:0001217  protein_coding_gene
#
#                                                 meta
# 0  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 1    {'types': ['Ontology', 'cliqueLeader', 'Node']}
# 2  {'http://www.geneontology.org/formats/oboInOwl...
# 3  {'http://www.geneontology.org/formats/oboInOwl...

# %%
reach_df.id.unique()
print('nodes: {}'.format(len(reach_df.id.unique())))
# Out:
# nodes: 4

# %%
reach_df['node_type'] = reach_df.id.apply(lambda x: x.split(':')[0])
reach_df.node_type.value_counts()
# Out:
# CHR            1
# MonarchData    1
# SO             1
# NCBITaxon      1
# Name: node_type, dtype: int64

# %%
# conclusion: reachables are taxon, chr, so

# %% [markdown]
# ## Edge Queries (Monarch)

# %%
# api address
api = 'https://api.monarchinitiative.org/api'
endpoint = '/bioentity'

# %%
# get gene info
r = requests.get('{}{}/gene/{}'.format(api,endpoint,gene))
#r = requests.get('https://api.monarchinitiative.org/api/bioentity/gene/%s/phenotypes/'%gene, headers={'Accept':'application/json'})
r.headers
r.json()
# Out:
# {'categories': ['gene', 'sequence feature'],
#  'chromosome': {'categories': None,
#   'consider': None,
#   'deprecated': None,
#   'description': None,
#   'id': None,
#   'label': None,
#   'replaced_by': None,
#   'synonyms': None,
#   'taxon': {'id': None, 'label': None},
#   'types': None,
#   'xrefs': None},
#  'consider': None,
#  'deprecated': None,
#  'description': None,
#  'disease_associations': [{'evidence_graph': {'edges': [{'obj': ':.well-known/genid/genoGM25347',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3200-1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126423'},
#      {'obj': ':.well-known/genid/610661.0004-610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25990'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:50962'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3200-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/OMIM610661-615273VL'},
#      {'obj': ':.well-known/genid/person-3200-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8'},
#      {'obj': ':.well-known/genid/genoGM25340',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3199-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3199-1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': ':.well-known/genid/406885-404454VL'},
#      {'obj': ':.well-known/genid/406885-404454VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': ':.well-known/genid/OMIM610661-615273VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'OMIM:610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': ':.well-known/genid/person-3199-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7'},
#      {'obj': 'OMIM:610661.0004',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3213-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/KEGG-hsa55768-OMIM615273VL'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a'},
#      {'obj': ':.well-known/genid/person-GM25990',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8'},
#      {'obj': ':.well-known/genid/610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25347'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0001'},
#      {'obj': 'OMIM:610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0001-610661.0002'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0002'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/OMIM610661-615273VL'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0003'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:126423'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-GM25990'},
#      {'obj': 'ECO:0000322',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:8a568df7358124fda2f7fdd2cead58e43c25a34c'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/406885-404454VL'},
#      {'obj': 'OMIM:610661.0003',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0003'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:126424'},
#      {'obj': 'ECO:0000220',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/KEGG-hsa55768-OMIM615273VL'},
#      {'obj': ':.well-known/genid/genoGM25389',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3213-1'},
#      {'obj': ':.well-known/genid/610661.0001-610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25340'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0005'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0004'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126424'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:50962'},
#      {'obj': ':.well-known/genid/genoGM25990',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-GM25990'},
#      {'obj': ':.well-known/genid/person-3213-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:50961'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:126422'},
#      {'obj': ':.well-known/genid/KEGG-hsa55768-OMIM615273VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:8a568df7358124fda2f7fdd2cead58e43c25a34c'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:50961'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126422'},
#      {'obj': 'OMIM:610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0002'},
#      {'obj': ':.well-known/genid/610661.0003',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25389'},
#      {'obj': 'OMIM:610661.0001',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0001-610661.0002'}],
#     'nodes': [{'id': ':.well-known/genid/person-3199-1',
#       'lbl': 'affected male proband with Congenital disorder of deglycosylation'},
#      {'id': 'ClinVarVariant:126423',
#       'lbl': 'NM_001145294.1(NGLY1):c.1079_1081delGAA (p.Arg360del)'},
#      {'id': ':.well-known/genid/person-3213-1',
#       'lbl': 'affected female proband with Congenital disorder of deglycosylation'},
#      {'id': ':.well-known/genid/610661.0004-610661.0005',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T)'},
#      {'id': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8', 'lbl': None},
#      {'id': 'ClinVarVariant:50961',
#       'lbl': 'NM_018297.3(NGLY1):c.1891delC (p.Gln631Serfs)'},
#      {'id': ':.well-known/genid/610661.0001-610661.0002',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC)'},
#      {'id': ':.well-known/genid/person-GM25990',
#       'lbl': 'affected female proband with Congenital disorder of deglycosylation'},
#      {'id': 'OMIM:610661.0002', 'lbl': 'NGLY1, ARG401TER'},
#      {'id': ':.well-known/genid/610661.0002', 'lbl': 'NGLY1(ARG401TER)'},
#      {'id': 'ECO:0000322',
#       'lbl': 'imported manually asserted information used in automatic assertion'},
#      {'id': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2', 'lbl': None},
#      {'id': ':.well-known/genid/genoGM25347',
#       'lbl': 'NGLY1(ARG401TER) [GM25347]'},
#      {'id': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a', 'lbl': None},
#      {'id': ':.well-known/genid/genoGM25340',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC) [GM25340]'},
#      {'id': ':.well-known/genid/person-3200-1',
#       'lbl': 'affected male proband with Congenital disorder of deglycosylation'},
#      {'id': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5', 'lbl': None},
#      {'id': 'OMIM:610661.0003', 'lbl': 'NGLY1, 1-BP DUP, 1370G'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ClinVarVariant:126424',
#       'lbl': 'NM_001145293.1(NGLY1):c.1570C>T (p.Arg524Ter)'},
#      {'id': 'MONARCH:8a568df7358124fda2f7fdd2cead58e43c25a34c', 'lbl': None},
#      {'id': 'OMIM:615273', 'lbl': 'NGLY1-deficiency'},
#      {'id': ':.well-known/genid/KEGG-hsa55768-OMIM615273VL',
#       'lbl': 'some variant of K01456 peptide-N4-(N-acetyl-beta-glucosaminyl)asparagine amidase [EC:3.5.1.52] | (RefSeq) NGLY1'},
#      {'id': 'OMIM:610661.0001', 'lbl': 'NGLY1, 1-BP DEL, 1891C'},
#      {'id': ':.well-known/genid/genoGM25990',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T) [GM25990]'},
#      {'id': 'ECO:0000220', 'lbl': 'sequencing assay evidence'},
#      {'id': ':.well-known/genid/610661.0003',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER)'},
#      {'id': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65', 'lbl': None},
#      {'id': ':.well-known/genid/OMIM610661-615273VL',
#       'lbl': 'some variant of NGLY1 that causes Congenital disorder of deglycosylation'},
#      {'id': ':.well-known/genid/genoGM25389',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER) [GM25389]'},
#      {'id': ':.well-known/genid/406885-404454VL',
#       'lbl': 'some variant of NGLY1 that is a disease-causing germline mutation(s) (loss of function) in Alacrimia-choreoathetosis-liver dysfunction syndrome'},
#      {'id': 'ClinVarVariant:126422',
#       'lbl': 'NM_018297.3(NGLY1):c.1370dupG (p.Arg458Lysfs)'},
#      {'id': 'ClinVarVariant:50962',
#       'lbl': 'NM_018297.3(NGLY1):c.1201A>T (p.Arg401Ter)'},
#      {'id': 'OMIM:610661.0005', 'lbl': 'NGLY1, ARG542TER'},
#      {'id': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7', 'lbl': None},
#      {'id': 'OMIM:610661.0004', 'lbl': 'NGLY1, 3-BP DEL, 1205TTC'}]},
#    'evidence_types': None,
#    'id': 'af89e914-68e5-4b3f-8d02-ee6d214a8a19',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'OMIM:615273',
#     'label': 'NGLY1-deficiency',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/kegg.ttl',
#     'http://data.monarchinitiative.org/ttl/orphanet.ttl',
#     'https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl',
#     'http://data.monarchinitiative.org/ttl/clinvar.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'families': None,
#  'full_name': None,
#  'function_associations': None,
#  'genotype_associations': [{'evidence_graph': {'edges': [{'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0001'},
#      {'obj': ':.well-known/genid/610661.0001-610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25340'},
#      {'obj': 'OMIM:610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0001-610661.0002'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0002'},
#      {'obj': 'OMIM:610661.0001',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0001-610661.0002'}],
#     'nodes': [{'id': ':.well-known/genid/genoGM25340',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC) [GM25340]'},
#      {'id': ':.well-known/genid/610661.0001-610661.0002',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC)'},
#      {'id': 'OMIM:610661.0001', 'lbl': 'NGLY1, 1-BP DEL, 1891C'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'OMIM:610661.0002', 'lbl': 'NGLY1, ARG401TER'}]},
#    'evidence_types': None,
#    'id': '0dd6333b-bf23-493c-ba41-f6f5a790084b',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': ':.well-known/genid/genoGM25340',
#     'label': 'NGLY1;NGLY1(ARG401TER;c.1891delC) [GM25340]',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'OMIM:610661.0003',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0003'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0003'},
#      {'obj': ':.well-known/genid/610661.0003',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25389'}],
#     'nodes': [{'id': ':.well-known/genid/610661.0003',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER)'},
#      {'id': ':.well-known/genid/genoGM25389',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER) [GM25389]'},
#      {'id': 'OMIM:610661.0003', 'lbl': 'NGLY1, 1-BP DUP, 1370G'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'}]},
#    'evidence_types': None,
#    'id': '607526bb-cf45-468c-b55f-f7f078b341a0',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': ':.well-known/genid/genoGM25389',
#     'label': 'NGLY1(c.1370dupG  R458FsTER) [GM25389]',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0002'},
#      {'obj': 'OMIM:610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0002'},
#      {'obj': ':.well-known/genid/610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25347'}],
#     'nodes': [{'id': ':.well-known/genid/genoGM25347',
#       'lbl': 'NGLY1(ARG401TER) [GM25347]'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'OMIM:610661.0002', 'lbl': 'NGLY1, ARG401TER'},
#      {'id': ':.well-known/genid/610661.0002', 'lbl': 'NGLY1(ARG401TER)'}]},
#    'evidence_types': None,
#    'id': '39604916-8893-49f2-a5e2-99b6e0a56ead',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': ':.well-known/genid/genoGM25347',
#     'label': 'NGLY1(ARG401TER) [GM25347]',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': ':.well-known/genid/610661.0004-610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25990'},
#      {'obj': 'OMIM:610661.0004',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0005'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0004'},
#      {'obj': 'OMIM:610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'}],
#     'nodes': [{'id': ':.well-known/genid/610661.0004-610661.0005',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T)'},
#      {'id': ':.well-known/genid/genoGM25990',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T) [GM25990]'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'OMIM:610661.0005', 'lbl': 'NGLY1, ARG542TER'},
#      {'id': 'OMIM:610661.0004', 'lbl': 'NGLY1, 3-BP DEL, 1205TTC'}]},
#    'evidence_types': None,
#    'id': '7ba448cb-28f6-485d-aa47-be39e986fa56',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': ':.well-known/genid/genoGM25990',
#     'label': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T) [GM25990]',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'homology_associations': [{'evidence_graph': {'edges': [{'obj': 'NCBIGene:173028',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:55768'},
#      {'obj': 'NCBIGene:173028',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:4b07d9439a590f8c626da2a772185e26d1d545ea'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:4b07d9439a590f8c626da2a772185e26d1d545ea'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:4b07d9439a590f8c626da2a772185e26d1d545ea'}],
#     'nodes': [{'id': 'MONARCH:4b07d9439a590f8c626da2a772185e26d1d545ea',
#       'lbl': None},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'NCBIGene:173028', 'lbl': 'png-1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '219116e0-af5b-4f4a-9f2f-420db0e56f29',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:173028',
#     'label': 'png-1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:6239', 'label': 'Caenorhabditis elegans'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000020',
#     'label': 'in 1 to 1 orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:8702',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:4cbef61da22309737567c80a8ac2a44dd9bd49f2'},
#      {'obj': 'ECO:0000079',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:4cbef61da22309737567c80a8ac2a44dd9bd49f2'},
#      {'obj': 'PMID:26186194',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:4cbef61da22309737567c80a8ac2a44dd9bd49f2'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:4cbef61da22309737567c80a8ac2a44dd9bd49f2'},
#      {'obj': 'NCBIGene:55768', 'pred': 'RO:0002434', 'sub': 'NCBIGene:8702'}],
#     'nodes': [{'id': 'MONARCH:4cbef61da22309737567c80a8ac2a44dd9bd49f2',
#       'lbl': None},
#      {'id': 'NCBIGene:8702', 'lbl': 'B4GALT4'},
#      {'id': 'ECO:0000079', 'lbl': 'affinity chromatography evidence'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'PMID:26186194', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '970518f9-63a9-4f3a-850f-6767a0e5abf9',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:8702',
#     'label': 'B4GALT4',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:26186194',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'PMID:22575648',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:62c41f5a7039767c72046a7a514084a4ac599ae1'},
#      {'obj': 'NCBIGene:5886', 'pred': 'RO:0002434', 'sub': 'NCBIGene:55768'},
#      {'obj': 'NCBIGene:55768', 'pred': 'RO:0002434', 'sub': 'NCBIGene:5886'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:ef86c2029bf948126c4c04769e8490cb74044a93'},
#      {'obj': 'ECO:0000324',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:62c41f5a7039767c72046a7a514084a4ac599ae1'},
#      {'obj': 'NCBIGene:5886',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:62c41f5a7039767c72046a7a514084a4ac599ae1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:ef86c2029bf948126c4c04769e8490cb74044a93'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:62c41f5a7039767c72046a7a514084a4ac599ae1'},
#      {'obj': 'NCBIGene:5886',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:ef86c2029bf948126c4c04769e8490cb74044a93'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:ef86c2029bf948126c4c04769e8490cb74044a93'}],
#     'nodes': [{'id': 'ECO:0000324', 'lbl': 'imaging assay evidence'},
#      {'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'MONARCH:62c41f5a7039767c72046a7a514084a4ac599ae1', 'lbl': None},
#      {'id': 'MONARCH:ef86c2029bf948126c4c04769e8490cb74044a93', 'lbl': None},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'PMID:22575648', 'lbl': None},
#      {'id': 'NCBIGene:5886', 'lbl': 'RAD23A'}]},
#    'evidence_types': None,
#    'id': 'a85fc30f-5edc-4388-aefd-9d52db22856f',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:5886',
#     'label': 'RAD23A',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:22575648',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None},
#     {'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:361014',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e83552d071c1dde2491b26da0373fdab0942349e'},
#      {'obj': 'NCBIGene:361014',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:55768'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e83552d071c1dde2491b26da0373fdab0942349e'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e83552d071c1dde2491b26da0373fdab0942349e'}],
#     'nodes': [{'id': 'NCBIGene:361014', 'lbl': 'Ngly1'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'MONARCH:e83552d071c1dde2491b26da0373fdab0942349e', 'lbl': None},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '0871bc2a-264b-487b-bfc5-0e78c346f788',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:361014',
#     'label': 'Ngly1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:10116', 'label': 'Rattus norvegicus'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000020',
#     'label': 'in 1 to 1 orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:533736',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:55768'},
#      {'obj': 'NCBIGene:533736',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:beb9b23a2a05ec412502c1469257a0d2431b34dc'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:beb9b23a2a05ec412502c1469257a0d2431b34dc'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:beb9b23a2a05ec412502c1469257a0d2431b34dc'}],
#     'nodes': [{'id': 'MONARCH:beb9b23a2a05ec412502c1469257a0d2431b34dc',
#       'lbl': None},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:533736', 'lbl': 'NGLY1'}]},
#    'evidence_types': None,
#    'id': '9bcd5d75-efe6-481f-abc9-d5cf3d139079',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:533736',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9913', 'label': 'Bos taurus'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000020',
#     'label': 'in 1 to 1 orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:5fe7f0df8cd72064265391194f66310df0728b16'},
#      {'obj': 'ECO:0000079',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:5fe7f0df8cd72064265391194f66310df0728b16'},
#      {'obj': 'NCBIGene:55768', 'pred': 'RO:0002434', 'sub': 'NCBIGene:1956'},
#      {'obj': 'PMID:24797263',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:5fe7f0df8cd72064265391194f66310df0728b16'},
#      {'obj': 'NCBIGene:1956',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:5fe7f0df8cd72064265391194f66310df0728b16'}],
#     'nodes': [{'id': 'NCBIGene:1956', 'lbl': 'EGFR'},
#      {'id': 'PMID:24797263', 'lbl': None},
#      {'id': 'MONARCH:5fe7f0df8cd72064265391194f66310df0728b16', 'lbl': None},
#      {'id': 'ECO:0000079', 'lbl': 'affinity chromatography evidence'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'}]},
#    'evidence_types': None,
#    'id': 'b82a86f7-c212-4cdd-9008-3fdb277c02b9',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:1956',
#     'label': 'EGFR',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:24797263',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:55768',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:553627'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:1763638529419199fbd9b5a8101857188aa9bec7'},
#      {'obj': 'NCBIGene:553627',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:51971e5c38cf4812c9dde9e229685884bc656e04'},
#      {'obj': 'ZFIN:ZDB-PUB-030905-1',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:51971e5c38cf4812c9dde9e229685884bc656e04'},
#      {'obj': 'NCBIGene:553627',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:1763638529419199fbd9b5a8101857188aa9bec7'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:51971e5c38cf4812c9dde9e229685884bc656e04'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:1763638529419199fbd9b5a8101857188aa9bec7'},
#      {'obj': 'ECO:0000031',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:51971e5c38cf4812c9dde9e229685884bc656e04'},
#      {'obj': 'NCBIGene:553627',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:55768'}],
#     'nodes': [{'id': 'MONARCH:51971e5c38cf4812c9dde9e229685884bc656e04',
#       'lbl': None},
#      {'id': 'NCBIGene:553627', 'lbl': 'ngly1'},
#      {'id': 'MONARCH:1763638529419199fbd9b5a8101857188aa9bec7', 'lbl': None},
#      {'id': 'ZFIN:ZDB-PUB-030905-1', 'lbl': None},
#      {'id': 'ECO:0000031',
#       'lbl': 'protein BLAST evidence used in manual assertion'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': 'a253b355-3161-47c8-a3fc-4e41156035dc',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:553627',
#     'label': 'ngly1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:7955', 'label': 'Danio rerio'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl',
#     'http://data.monarchinitiative.org/ttl/zfin.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'ZFIN:ZDB-PUB-030905-1',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:7415',
#       'pred': 'RO:0002434',
#       'sub': 'NCBIGene:55768'},
#      {'obj': 'NCBIGene:55768', 'pred': 'RO:0002434', 'sub': 'NCBIGene:7415'},
#      {'obj': 'ECO:0000079',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9'},
#      {'obj': 'ECO:0000085',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9'},
#      {'obj': 'NCBIGene:7415',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9'},
#      {'obj': 'PMID:22119785',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9'},
#      {'obj': 'NCBIGene:7415',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:c1b8765a5091d73fa55755e0dda89711c288656d'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:c1b8765a5091d73fa55755e0dda89711c288656d'},
#      {'obj': 'PMID:15362974',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:c1b8765a5091d73fa55755e0dda89711c288656d'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9'},
#      {'obj': 'ECO:0000085',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:c1b8765a5091d73fa55755e0dda89711c288656d'},
#      {'obj': 'ECO:0000079',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:c1b8765a5091d73fa55755e0dda89711c288656d'},
#      {'obj': 'PMID:16807242',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9'}],
#     'nodes': [{'id': 'PMID:16807242', 'lbl': None},
#      {'id': 'NCBIGene:7415', 'lbl': 'VCP'},
#      {'id': 'MONARCH:8befb81f0e28c3e459e79eb5b8ac2fa2146367e9', 'lbl': None},
#      {'id': 'ECO:0000079', 'lbl': 'affinity chromatography evidence'},
#      {'id': 'PMID:22119785', 'lbl': None},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ECO:0000085', 'lbl': 'immunoprecipitation evidence'},
#      {'id': 'MONARCH:c1b8765a5091d73fa55755e0dda89711c288656d', 'lbl': None},
#      {'id': 'PMID:15362974', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'deac23f8-511f-4ec1-9b5a-affcc7c043f1',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:7415',
#     'label': 'VCP',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:22119785',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None},
#     {'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:15362974',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None},
#     {'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:16807242',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'PMID:21832049',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:450a4ce4ff063fc62ba1cef8aeb242931ebceff2'},
#      {'obj': 'NCBIGene:351', 'pred': 'RO:0002434', 'sub': 'NCBIGene:55768'},
#      {'obj': 'ECO:0000085',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:450a4ce4ff063fc62ba1cef8aeb242931ebceff2'},
#      {'obj': 'NCBIGene:351',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:450a4ce4ff063fc62ba1cef8aeb242931ebceff2'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:450a4ce4ff063fc62ba1cef8aeb242931ebceff2'}],
#     'nodes': [{'id': 'NCBIGene:351', 'lbl': 'APP'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ECO:0000085', 'lbl': 'immunoprecipitation evidence'},
#      {'id': 'MONARCH:450a4ce4ff063fc62ba1cef8aeb242931ebceff2', 'lbl': None},
#      {'id': 'PMID:21832049', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'c9d6f604-18c2-4462-af07-b03170b7587a',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:351',
#     'label': 'APP',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:21832049',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:100059456',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:3b63d6806cb81fb8399fecf8ee05f271026cfacc'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:3b63d6806cb81fb8399fecf8ee05f271026cfacc'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:3b63d6806cb81fb8399fecf8ee05f271026cfacc'},
#      {'obj': 'NCBIGene:100059456',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:55768'}],
#     'nodes': [{'id': 'MONARCH:3b63d6806cb81fb8399fecf8ee05f271026cfacc',
#       'lbl': None},
#      {'id': 'NCBIGene:100059456', 'lbl': 'NGLY1'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '722602b1-4343-43da-b80e-abcdb87e3601',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:100059456',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9796', 'label': 'Equus caballus'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000020',
#     'label': 'in 1 to 1 orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'id': 'NCBIGene:55768',
#  'interaction_associations': None,
#  'label': 'NGLY1',
#  'literature_associations': None,
#  'pathway_associations': None,
#  'phenotype_associations': [{'evidence_graph': {'edges': [{'obj': ':.well-known/genid/genoGM25347',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3200-1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126423'},
#      {'obj': ':.well-known/genid/610661.0004-610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25990'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:50962'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3200-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/OMIM610661-615273VL'},
#      {'obj': ':.well-known/genid/person-3200-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8'},
#      {'obj': ':.well-known/genid/genoGM25340',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3199-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3199-1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': ':.well-known/genid/406885-404454VL'},
#      {'obj': ':.well-known/genid/406885-404454VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': 'HP:0200055', 'pred': 'RO:0002200', 'sub': 'OMIM:615273'},
#      {'obj': ':.well-known/genid/OMIM610661-615273VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'OMIM:610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': ':.well-known/genid/person-3199-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7'},
#      {'obj': 'OMIM:610661.0004',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3213-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
# ...
#      {'id': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2', 'lbl': None},
#      {'id': ':.well-known/genid/genoGM25347',
#       'lbl': 'NGLY1(ARG401TER) [GM25347]'},
#      {'id': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a', 'lbl': None},
#      {'id': ':.well-known/genid/genoGM25340',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC) [GM25340]'},
#      {'id': ':.well-known/genid/person-3200-1',
#       'lbl': 'affected male proband with Congenital disorder of deglycosylation'},
#      {'id': 'HP:0001252', 'lbl': 'Muscular hypotonia'},
#      {'id': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5', 'lbl': None},
#      {'id': 'OMIM:610661.0003', 'lbl': 'NGLY1, 1-BP DUP, 1370G'},
#      {'id': 'ECO:0000501', 'lbl': 'evidence used in automatic assertion'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ClinVarVariant:126424',
#       'lbl': 'NM_001145293.1(NGLY1):c.1570C>T (p.Arg524Ter)'},
#      {'id': 'OMIM:615273', 'lbl': 'NGLY1-deficiency'},
#      {'id': 'OMIM:610661.0001', 'lbl': 'NGLY1, 1-BP DEL, 1891C'},
#      {'id': ':.well-known/genid/genoGM25990',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T) [GM25990]'},
#      {'id': 'ECO:0000220', 'lbl': 'sequencing assay evidence'},
#      {'id': ':.well-known/genid/610661.0003',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER)'},
#      {'id': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65', 'lbl': None},
#      {'id': ':.well-known/genid/OMIM610661-615273VL',
#       'lbl': 'some variant of NGLY1 that causes Congenital disorder of deglycosylation'},
#      {'id': ':.well-known/genid/genoGM25389',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER) [GM25389]'},
#      {'id': ':.well-known/genid/406885-404454VL',
#       'lbl': 'some variant of NGLY1 that is a disease-causing germline mutation(s) (loss of function) in Alacrimia-choreoathetosis-liver dysfunction syndrome'},
#      {'id': 'ClinVarVariant:126422',
#       'lbl': 'NM_018297.3(NGLY1):c.1370dupG (p.Arg458Lysfs)'},
#      {'id': 'ClinVarVariant:50962',
#       'lbl': 'NM_018297.3(NGLY1):c.1201A>T (p.Arg401Ter)'},
#      {'id': 'OMIM:610661.0005', 'lbl': 'NGLY1, ARG542TER'},
#      {'id': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7', 'lbl': None},
#      {'id': 'OMIM:610661.0004', 'lbl': 'NGLY1, 3-BP DEL, 1205TTC'}]},
#    'evidence_types': None,
#    'id': '3f7fc47c-dfd6-4aee-b628-135db349b3c3',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'HP:0001252',
#     'label': 'Muscular hypotonia',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/orphanet.ttl',
#     'https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl',
#     'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#     'http://data.monarchinitiative.org/ttl/hpoa.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': ':.well-known/genid/genoGM25347',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3200-1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126423'},
#      {'obj': ':.well-known/genid/610661.0004-610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25990'},
#      {'obj': 'ECO:0000501',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:fdfd1af7aeeb2c9513c7d42f3fb35ad2ba3bdb76'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:50962'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3200-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/OMIM610661-615273VL'},
#      {'obj': ':.well-known/genid/person-3200-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8'},
#      {'obj': ':.well-known/genid/genoGM25340',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3199-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3199-1'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': ':.well-known/genid/406885-404454VL'},
#      {'obj': ':.well-known/genid/406885-404454VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': ':.well-known/genid/OMIM610661-615273VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': 'OMIM:610661.0005',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': ':.well-known/genid/person-3199-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7'},
#      {'obj': 'HP:0004305',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:fdfd1af7aeeb2c9513c7d42f3fb35ad2ba3bdb76'},
#      {'obj': 'OMIM:610661.0004',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0004-610661.0005'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-3213-1'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a'},
#      {'obj': ':.well-known/genid/person-GM25990',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:fdfd1af7aeeb2c9513c7d42f3fb35ad2ba3bdb76'},
#      {'obj': ':.well-known/genid/610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25347'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0001'},
#      {'obj': 'OMIM:610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0001-610661.0002'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0002'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/OMIM610661-615273VL'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0003'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:126423'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/person-GM25990'},
#      {'obj': 'ECO:0000322',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2'},
#      {'obj': 'OMIM:615273',
#       'pred': 'RO:0002200',
#       'sub': ':.well-known/genid/406885-404454VL'},
#      {'obj': 'OMIM:610661.0003',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0003'},
#      {'obj': 'OMIM:615273',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:126424'},
#      {'obj': 'ECO:0000220',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5'},
#      {'obj': ':.well-known/genid/genoGM25389',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-3213-1'},
#      {'obj': ':.well-known/genid/610661.0001-610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25340'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0005'},
#      {'obj': 'HP:0004305', 'pred': 'RO:0002200', 'sub': 'OMIM:615273'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000408',
#       'sub': 'OMIM:610661.0004'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126424'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:50962'},
#      {'obj': ':.well-known/genid/genoGM25990',
#       'pred': 'GENO:0000222',
#       'sub': ':.well-known/genid/person-GM25990'},
#      {'obj': ':.well-known/genid/person-3213-1',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:126422'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:50961'},
#      {'obj': 'OMIM:615273',
#       'pred': 'GENO:0000840',
#       'sub': 'ClinVarVariant:50961'},
#      {'obj': 'NCBIGene:55768',
#       'pred': 'GENO:0000418',
#       'sub': 'ClinVarVariant:126422'},
#      {'obj': ':.well-known/genid/610661.0003',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/genoGM25389'},
#      {'obj': 'OMIM:610661.0002',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0002'},
#      {'obj': 'OMIM:610661.0001',
#       'pred': 'GENO:0000382',
#       'sub': ':.well-known/genid/610661.0001-610661.0002'}],
#     'nodes': [{'id': ':.well-known/genid/person-3199-1',
#       'lbl': 'affected male proband with Congenital disorder of deglycosylation'},
#      {'id': 'ClinVarVariant:126423',
#       'lbl': 'NM_001145294.1(NGLY1):c.1079_1081delGAA (p.Arg360del)'},
#      {'id': ':.well-known/genid/610661.0004-610661.0005',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T)'},
#      {'id': ':.well-known/genid/person-3213-1',
#       'lbl': 'affected female proband with Congenital disorder of deglycosylation'},
#      {'id': 'MONARCH:a78544aa0feaec55807c289ba3d6aedadb69dbd8', 'lbl': None},
#      {'id': 'ClinVarVariant:50961',
#       'lbl': 'NM_018297.3(NGLY1):c.1891delC (p.Gln631Serfs)'},
#      {'id': ':.well-known/genid/610661.0001-610661.0002',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC)'},
#      {'id': ':.well-known/genid/person-GM25990',
#       'lbl': 'affected female proband with Congenital disorder of deglycosylation'},
#      {'id': 'OMIM:610661.0002', 'lbl': 'NGLY1, ARG401TER'},
#      {'id': ':.well-known/genid/610661.0002', 'lbl': 'NGLY1(ARG401TER)'},
#      {'id': 'ECO:0000322',
#       'lbl': 'imported manually asserted information used in automatic assertion'},
#      {'id': 'MONARCH:665c1d3fbfc3abb0c5dc366dba0731358265d0f2', 'lbl': None},
#      {'id': ':.well-known/genid/genoGM25347',
#       'lbl': 'NGLY1(ARG401TER) [GM25347]'},
#      {'id': 'MONARCH:8ece42278dc99592834ea5e667d42545d79f409a', 'lbl': None},
#      {'id': ':.well-known/genid/genoGM25340',
#       'lbl': 'NGLY1;NGLY1(ARG401TER;c.1891delC) [GM25340]'},
#      {'id': ':.well-known/genid/person-3200-1',
#       'lbl': 'affected male proband with Congenital disorder of deglycosylation'},
#      {'id': 'MONARCH:980debcc2bf23bbd566978b66e42e8d7034e0df5', 'lbl': None},
#      {'id': 'OMIM:610661.0003', 'lbl': 'NGLY1, 1-BP DUP, 1370G'},
#      {'id': 'ECO:0000501', 'lbl': 'evidence used in automatic assertion'},
#      {'id': 'NCBIGene:55768', 'lbl': 'NGLY1'},
#      {'id': 'ClinVarVariant:126424',
#       'lbl': 'NM_001145293.1(NGLY1):c.1570C>T (p.Arg524Ter)'},
#      {'id': 'HP:0004305', 'lbl': 'Involuntary movements'},
#      {'id': 'OMIM:615273', 'lbl': 'NGLY1-deficiency'},
#      {'id': 'OMIM:610661.0001', 'lbl': 'NGLY1, 1-BP DEL, 1891C'},
#      {'id': ':.well-known/genid/genoGM25990',
#       'lbl': 'NGLY1;NGLY1(3-BP DEL  1205 TTC;ARG542TER  c.1570C>T) [GM25990]'},
#      {'id': 'ECO:0000220', 'lbl': 'sequencing assay evidence'},
#      {'id': ':.well-known/genid/610661.0003',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER)'},
#      {'id': 'MONARCH:4d8303fb4655006e8df2cb50e32740b91d6c3e65', 'lbl': None},
#      {'id': ':.well-known/genid/OMIM610661-615273VL',
#       'lbl': 'some variant of NGLY1 that causes Congenital disorder of deglycosylation'},
#      {'id': ':.well-known/genid/genoGM25389',
#       'lbl': 'NGLY1(c.1370dupG  R458FsTER) [GM25389]'},
#      {'id': ':.well-known/genid/406885-404454VL',
#       'lbl': 'some variant of NGLY1 that is a disease-causing germline mutation(s) (loss of function) in Alacrimia-choreoathetosis-liver dysfunction syndrome'},
#      {'id': 'ClinVarVariant:126422',
#       'lbl': 'NM_018297.3(NGLY1):c.1370dupG (p.Arg458Lysfs)'},
#      {'id': 'ClinVarVariant:50962',
#       'lbl': 'NM_018297.3(NGLY1):c.1201A>T (p.Arg401Ter)'},
#      {'id': 'OMIM:610661.0005', 'lbl': 'NGLY1, ARG542TER'},
#      {'id': 'MONARCH:fdfd1af7aeeb2c9513c7d42f3fb35ad2ba3bdb76', 'lbl': None},
#      {'id': 'MONARCH:42d05e731935a651eaf999c2aeb046987f01cca7', 'lbl': None},
#      {'id': 'OMIM:610661.0004', 'lbl': 'NGLY1, 3-BP DEL, 1205TTC'}]},
#    'evidence_types': None,
#    'id': 'eb6c9fb2-961a-4b38-a2a9-ea01b15b5cc8',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'HP:0004305',
#     'label': 'Involuntary movements',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/orphanet.ttl',
#     'https://data.monarchinitiative.org/ttl/omim.ttl',
#     'http://data.monarchinitiative.org/ttl/coriell.ttl',
#     'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#     'http://data.monarchinitiative.org/ttl/hpoa.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:55768',
#     'label': 'NGLY1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'replaced_by': None,
#  'sequence_features': None,
#  'summaries': None,
#  'synonyms': [{'pred': 'synonym', 'val': 'FLJ12409', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'NGLY1', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'LOC95041', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'hPNGase', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'NGLY1_HUMAN', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'PNG1', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'peptide:N-glycanase', 'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#    'xrefs': None},
#   {'pred': 'synonym', 'val': 'N-glycanase 1', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'PNGase', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'CDG1V', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'CDDG', 'xrefs': None}],
#  'systematic_name': None,
#  'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#  'transcripts': None,
#  'types': None,
#  'xrefs': None}

# %%
with open('{}_id.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
# get gene-gene interactions
r = requests.get('{}{}/gene/{}/interactions/'.format(api,endpoint,gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 17

# %%
with open('{}_interactions.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
ggi_df = json_normalize(r.json(), 'objects')
ggi_df.columns = ['gene_id']
ggi_df.head(2)
# Out:
#           gene_id
# 0  NCBIGene:10906
# 1  NCBIGene:11124

# %%
ggi_df.to_csv('{}_ggi.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get gene-phenotype
r = requests.get('{}{}/gene/{}/phenotypes/'.format(api,endpoint,gene))
nassociations = len(r.json()['associations'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 8

# %%
with open('{}_phenotypes.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
gph_df = json_normalize(r.json(), 'objects')
gph_df.columns = ['phenotype_id']
gph_df.head(2)
# Out:
#   phenotype_id
# 0   HP:0001252
# 1   HP:0001263

# %%
gph_df.to_csv('{}_gene_phenotype.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# Get gene-disease
r = requests.get('{}{}/gene/{}/diseases/'.format(api,endpoint,gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 1

# %%
with open('{}_diseases.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
r_dict = r.json()
gda_df = json_normalize(r_dict, 'objects')
gda_df.columns = ['disease_id']
gda_df.head(2)
# Out:
#     disease_id
# 0  OMIM:615273

# %%
gda_df.to_csv('{}_gene_disease.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get gene-function
r = requests.get('{}{}/gene/{}/function/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
r.json()
# Out:
# Number of nodes associated are 0
# {'associations': [],
#  'compact_associations': None,
#  'facet_counts': {'isa_partof_closure': {}, 'taxon_label': {}},
#  'facet_pivot': None,
#  'numFound': None,
#  'objects': [],
#  'start': None}

# %%
# get gene-expressedInAnatomy
r = requests.get('{}{}/gene/{}/expressed/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 20

# %%
with open('{}_expressed.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
r_data = r.json()
gaa_df = json_normalize(r_data, 'objects')
gaa_df.columns = ['anatomy_id']
gaa_df.head(2)
# Out:
#        anatomy_id
# 0      CL:0002328
# 1  UBERON:0000007

# %%
gaa_df.to_csv('{}_gene_anatomy.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get gene-pub
r = requests.get('{}{}/gene/{}/pubs/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 0

# %%
# get gene-homolog
r = requests.get('{}{}/gene/{}/homologs/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 14

# %%
with open('{}_homologs.json'.format(path), 'w') as f:
    json.dump(r.json(), f, sort_keys=True, indent=4)

# %%
r_dict = r.json()
gha_df = json_normalize(r_dict, 'objects')
gha_df.columns = ['homolog_id']
gha_df.head(2)
# Out:
#             homolog_id
# 0  FlyBase:FBgn0033050
# 1          MGI:1913276

# %%
gha_df.to_csv('{}_gene_homolog.tsv'.format(path), sep='\t', index=False, header=True)

# %% [markdown]
# ## Query Wikidata for Knowldege.Bio

# %%
# api address:
api = 'https://query.wikidata.org/sparql'

# %%
def generate_table(header, results):
    df = {}
    for res_d in results:
        for head in header:
            df[head] = []
        
    for res_d in results:
        for head in header:
            try:
                value = res_d[head]['value']
            except:
                value = 'NA'
            if value.startswith('http'):
                namespace, value = value.rsplit('/', 1)
            aux = df[head]
            aux.append(value)
            df[head] = aux
            
    try:
        results_df = pd.DataFrame.from_dict(df)
    except e:
        print(e)
        print(df)
        
    results_df = results_df[header]
    return results_df

# %%
# get NCBIGene:
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  {?item wdt:P351 ?id .} # ncbi gene
  values ?id {"55768"}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

# %%
r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})

# %%
header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)
df
# Out:
#       id       item itemLabel                                    altLabel  \
# 0  55768  Q18042037     NGLY1  CDDG|CDG1V|N-glycanase 1|NGLY1|PNG1|PNGase
#
#                                           itemDesc
# 0  protein-coding gene in the species Homo sapiens

# %%
df.to_csv('{}_subject_concept_kb.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get uberon
# get input_list
input_df = pd.read_table('/home/nuria/workspace/monarch/ngly1_human_expansion/ngly1_human_gene_anatomy.tsv')
input_df = input_df[input_df.anatomy_id.str.contains('UBERON')]
input_df['id'] = input_df.anatomy_id.apply(lambda x: '"' + str(x.split(':')[1]) + '"')
input_l = list(input_df['id'])
input_s = ' '.join(input_l)
input_s
# Out:
# '"0000007" "0000014" "0000074" "0000167" "0000922" "0000945" "0001103" "0001166" "0001264" "0001304" "0001723" "0002358" "0004358" "0004359" "0004736" "0004801" "0007371" "0007616" "0011876"'

# %%
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  # ?item wdt:P1554 ?id .
  values ?id {""" + input_s + """}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

# %%
r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})
#r.json()

# %%
header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)
df.head(2)
# Out:
#         id       item                   itemLabel altLabel itemDesc
# 0  0000945   Q1029907                     stomach                NA
# 1  0007371  Q30030505  superior surface of tongue                NA

# %%
# merge input with response
input_df = input_df[['anatomy_id']]
input_df['id'] = input_df.anatomy_id.apply(lambda x: x.split(':')[1])
output_df = input_df.merge(df, how="left")
output_df = output_df[['anatomy_id', 'item', 'itemLabel', 'altLabel', 'itemDesc']]
output_df.head(2)
# Out:
#        anatomy_id       item        itemLabel    altLabel         itemDesc
# 0  UBERON:0000007    Q156871  pituitary gland  hypophysis  endocrine gland
# 1  UBERON:0000014  Q30029801     zone of skin                           NA

# %%
output_df.to_csv('{}_anatomies_concept_kb.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get orthologs (ncbigene)
# get input_list
input_df = pd.read_table('/home/nuria/workspace/monarch/ngly1_human_expansion/ngly1_human_gene_homolog.tsv')
input_df = input_df[input_df.homolog_id.str.contains('NCBIGene')]
input_df['id'] = input_df.homolog_id.apply(lambda x: '"' + str(x.split(':')[1]) + '"')
input_l = list(input_df['id'])
input_s = ' '.join(input_l)
input_s
# Out:
# '"100031666" "100059456" "100522951" "100562703" "100682555" "173028" "361014" "460233" "533736" "553627" "700842" "835019"'

# %%
# query
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  {?item wdt:P351 ?id .} # ncbi gene
  values ?id {""" + input_s + """}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

# %%
r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})
#r.json()

# %%
header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)
df.head(2)
# Out:
#        id       item itemLabel       altLabel  \
# 0  533736  Q30031022     NGLY1  N-glycanase 1
# 1  700842  Q30031074     NGLY1  N-glycanase 1
#
#                                             itemDesc
# 0      protein-coding gene in the species Bos taurus
# 1  protein-coding gene in the species Macaca mulatta

# %%
# merge input with response
input_df = input_df[['homolog_id']]
input_df['id'] = input_df.homolog_id.apply(lambda x: x.split(':')[1])
output_df = input_df.merge(df, how="left")
output_df = output_df[['homolog_id', 'item', 'itemLabel', 'altLabel', 'itemDesc']]
output_df.head(2)
# Out:
#            homolog_id       item itemLabel       altLabel  \
# 0  NCBIGene:100031666  Q30030707     NGLY1  N-glycanase 1
# 1  NCBIGene:100059456  Q30030795     NGLY1  N-glycanase 1
#
#                                             itemDesc
# 0  protein-coding gene in the species Monodelphis...
# 1  protein-coding gene in the species Equus caballus

# %%
ncbigene_df = output_df

# %%
# get orthologs (mgi)
# get input_list
input_df = pd.read_table('/home/nuria/workspace/monarch/ngly1_human_expansion/ngly1_human_gene_homolog.tsv')
input_df = input_df[input_df.homolog_id.str.contains('MGI')]
input_df['id'] = input_df.homolog_id.apply(lambda x: '"' + str(x) + '"')
input_l = list(input_df['id'])
input_s = ' '.join(input_l)
input_s
# Out:
# '"MGI:1913276"'

# %%
# query
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  {?item wdt:P671 ?id .} # mgi gene
  values ?id {""" + input_s + """}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})
#r.json()

header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)
df.head(2)

# merge input with response
input_df = input_df[['homolog_id']]
input_df['id'] = input_df.homolog_id
output_df = input_df.merge(df, how="left")
output_df = output_df[['homolog_id', 'item', 'itemLabel', 'altLabel', 'itemDesc']]
mgi_df = output_df
output_df.head(2)
# Out:
#     homolog_id       item itemLabel  \
# 0  MGI:1913276  Q18258933     Ngly1
#
#                                         altLabel  \
# 0  N-glycanase 1|PNGase|Ngly1|1110002C09Rik|Png1
#
#                                           itemDesc
# 0  protein-coding gene in the species Mus musculus

# %%
# get orthologs (fly) 
# get input_list
input_df = pd.read_table('/home/nuria/workspace/monarch/ngly1_human_expansion/ngly1_human_gene_homolog.tsv')
input_df = input_df[input_df.homolog_id.str.contains('FlyBase')]
input_df['id'] = input_df.homolog_id.apply(lambda x: '"' + str(x.split(':')[1]) + '"')
input_l = list(input_df['id'])
input_s = ' '.join(input_l)
input_s
# Out:
# '"FBgn0033050"'

# %%
# query
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  {?item wdt:P3852 ?id .} # ncbi gene
  values ?id {""" + input_s + """}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})
#r.json()

header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)
df.head(2)

# merge input with response
input_df = input_df[['homolog_id']]
input_df['id'] = input_df.homolog_id.apply(lambda x: x.split(':')[1])
output_df = input_df.merge(df, how="left")
output_df = output_df[['homolog_id', 'item', 'itemLabel', 'altLabel', 'itemDesc']]
fly_df = output_df
output_df.head(2)
# Out:
#             homolog_id       item itemLabel  \
# 0  FlyBase:FBgn0033050  Q29733620      Pngl
#
#                                             altLabel  \
# 0  PNGase|CG7865|Dmel_CG7865|Dmel\CG7865|png1|PNG...
#
#                                             itemDesc
# 0  protein-coding gene in the species Drosophila ...

# %%
output_df = pd.concat([fly_df,mgi_df,ncbigene_df])
output_df
# Out:
#              homolog_id       item itemLabel  \
# 0   FlyBase:FBgn0033050  Q29733620      Pngl
# 0           MGI:1913276  Q18258933     Ngly1
# 0    NCBIGene:100031666  Q30030707     NGLY1
# 1    NCBIGene:100059456  Q30030795     NGLY1
# 2    NCBIGene:100522951  Q30030866     NGLY1
# 3    NCBIGene:100562703  Q30030907     NGLY1
# 4    NCBIGene:100682555  Q30030945     NGLY1
# 5       NCBIGene:173028  Q29697143     png-1
# 6       NCBIGene:361014  Q24413748     Ngly1
# 7       NCBIGene:460233  Q30030979     NGLY1
# 8       NCBIGene:533736  Q30031022     NGLY1
# 9       NCBIGene:553627  Q29767016     ngly1
# 10      NCBIGene:700842  Q30031074     NGLY1
# 11      NCBIGene:835019  Q30031126      PNG1
#
#                                              altLabel  \
# 0   PNGase|CG7865|Dmel_CG7865|Dmel\CG7865|png1|PNG...
# 0       N-glycanase 1|PNGase|Ngly1|1110002C09Rik|Png1
# 0                                       N-glycanase 1
# 1                                       N-glycanase 1
# 2                                       N-glycanase 1
# 3                                       N-glycanase 1
# 4                                       N-glycanase 1
# 5   CELE_F56G4.5|Peptide-N(4)-(N-acetyl-beta-gluco...
# 6                                 N-glycanase 1|Ngly1
# 7                                       N-glycanase 1
# 8                                       N-glycanase 1
# 9                 N-glycanase 1|im:6895151|zgc:110561
# 10                                      N-glycanase 1
# 11                              peptide-N-glycanase 1
#
#                                              itemDesc
# 0   protein-coding gene in the species Drosophila ...
# 0     protein-coding gene in the species Mus musculus
# 0   protein-coding gene in the species Monodelphis...
# 1   protein-coding gene in the species Equus caballus
# 2       protein-coding gene in the species Sus scrofa
# 3   protein-coding gene in the species Anolis caro...
# 4   protein-coding gene in the species Canis lupus...
# 5   protein-coding gene in the species Caenorhabdi...
# 6   protein-coding gene in the species Rattus norv...
# 7   protein-coding gene in the species Pan troglod...
# 8       protein-coding gene in the species Bos taurus
# 9      protein-coding gene in the species Danio rerio
# 10  protein-coding gene in the species Macaca mulatta
# 11  protein-coding gene in the species Arabidopsis...

# %%
output_df.to_csv('{}_homologs_concept_kb.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get NCBIGene (ggi):
# get input_list
input_df = pd.read_table('/home/nuria/workspace/monarch/ngly1_human_expansion/ngly1_human_ggi.tsv')
input_df['id'] = input_df.gene_id.apply(lambda x: '"' + str(x.split(':')[1]) + '"')
input_l = list(input_df['id'])
input_s = ' '.join(input_l)
input_s
# Out:
# '"10906" "11124" "137886" "1956" "26270" "29979" "351" "55968" "57159" "5886" "5887" "6733" "7415" "79139" "83606" "84866" "8702"'

# %%
# query
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  {?item wdt:P351 ?id .} # ncbi gene
  values ?id {""" + input_s + """}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})
#r.json()

# %%
header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)

# merge input with response
input_df = input_df[['gene_id']]
input_df['id'] = input_df.gene_id.apply(lambda x: x.split(':')[1])
output_df = input_df.merge(df, how="left")
output_df = output_df[['gene_id', 'item', 'itemLabel', 'altLabel', 'itemDesc']]
output_df.head(2)
# Out:
#           gene_id       item itemLabel  \
# 0  NCBIGene:10906  Q18035937    TRAFD1
# 1  NCBIGene:11124  Q18036138      FAF1
#
#                                             altLabel  \
# 0  FLN29|TRAF-type zinc finger domain containing ...
# 1  CGI-03|FAF1|Fas associated factor 1|hFAF1|HFAF...
#
#                                           itemDesc
# 0  protein-coding gene in the species Homo sapiens
# 1  protein-coding gene in the species Homo sapiens

# %%
output_df.to_csv('{}_ncbi_interactors_concept_kb.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get phenotypes (hp)
# get input_list
input_df = pd.read_table('/home/nuria/workspace/monarch/ngly1_human_expansion/ngly1_human_gene_phenotype.tsv')
input_df = input_df[input_df.phenotype_id.str.contains('HP')]
input_df['id'] = input_df.phenotype_id.apply(lambda x: '"' + str(x) + '"')
input_l = list(input_df['id'])
input_s = ' '.join(input_l)
input_s
# Out:
# '"HP:0001252" "HP:0001263" "HP:0001773" "HP:0002910" "HP:0004305" "HP:0009830" "HP:0012448" "HP:0200055"'

# %%
# query
query = """SELECT DISTINCT ?id ?item ?itemLabel (group_concat(distinct ?itemaltLabel; separator="|") as ?altLabel) ?itemDesc
WHERE
{
  {?item wdt:P3841 ?id .} # mgi gene
  values ?id {""" + input_s + """}
  OPTIONAL{
  # ?item skos:altLabel ?itemaltLabel .
    FILTER(LANG(?itemaltLabel) = "en")
  # ?item schema:description ?itemDesc .
    FILTER(LANG(?itemDesc) = "en")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
group by ?item ?id ?itemLabel ?itemDesc"""

r = requests.post(api, data={'query': query}, headers={'Accept':'application/sparql-results+json'})
#r.json()

# %%
header_l = r.json()['head']['vars']
results_l = r.json()['results']['bindings']
df = generate_table(header_l, results_l)
df.head(2)

# merge input with response
input_df = input_df[['phenotype_id']]
input_df['id'] = input_df.phenotype_id
output_df = input_df.merge(df, how="left")
output_df = output_df[['phenotype_id', 'item', 'itemLabel', 'altLabel', 'itemDesc']]
output_df.head(2)
# Out:
#   phenotype_id      item                 itemLabel  \
# 0   HP:0001252  Q1753547                 Hypotonia
# 1   HP:0001263  Q1142806  developmental disability
#
#                              altLabel                    itemDesc
# 0  Low Muscle Tone|Muscular hypotonia  Abnormally low muscle tone
# 1                                                              NA

# %%
output_df.to_csv('{}_phenotypes_concept_kb.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get taxon, chr, so
